# %%
import os
os.environ["OPENAI_API_KEY"] = 'YOUR_OPENAI_KEY'

# %%
from src import evaluator as Evaluator

# %%
evaluator = Evaluator.DistributeWiseEvaluator(model_name_or_path='codellama/CodeLlama-34b-Instruct-hf', do_generate=False)

# %%
# output = evaluator.generate(num_samples_per_task=1)

# %%
output = evaluator.evaluate(num_samples_per_task=1)
# Out:
# 100%|██████████| 256/256 [16:36<00:00,  3.89s/it]
# Pass@1: 0.5703125 Beyond@1: 0.4504571251916817
